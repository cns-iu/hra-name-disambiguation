# %%
import sklearn

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import hashlib

# Load data
author_id = pd.read_csv('D://id.csv', dtype=str)
author_name = pd.read_csv('D://name.csv', dtype=str)
author_affiliation = pd.read_csv('D://affiliation.csv', dtype=str)

# Standardize author names to lowercase
author_name['name'] = author_name['name'].str.lower()

# Fill missing ORCID with a placeholder
author_id['orcid'].fillna('unknown', inplace=True)

# Merge the DataFrames on the common identifiers
merged_data = author_name.merge(author_id, left_on='auth_id', right_on='ident', how='left')
merged_data = merged_data.merge(author_affiliation, on=['pmid', 'auth_id'], how='left')

# Drop unnecessary columns
merged_data.drop(columns=['ident', 'source', 'identifier'], inplace=True)

# Create a unique identifier for each author entry
merged_data['unique_id'] = merged_data['pmid'] + '_' + merged_data['auth_id']

# Shorten unique_id using a hash function
merged_data['short_unique_id'] = merged_data['unique_id'].apply(lambda x: hashlib.sha1(x.encode()).hexdigest()[:10])

# Handle missing values in the merged DataFrame
merged_data.fillna('unknown', inplace=True)

# Remove duplicate short_unique_id
merged_data = merged_data.drop_duplicates(subset=['short_unique_id'])

# Display the cleaned and merged DataFrame
print(merged_data.head())

# Feature Engineering
le = LabelEncoder()
merged_data['auth_id'] = le.fit_transform(merged_data['auth_id'])
merged_data['affiliation'] = le.fit_transform(merged_data['affiliation'])
merged_data['fore_name'] = le.fit_transform(merged_data['fore_name'])
merged_data['last_name'] = le.fit_transform(merged_data['last_name'])

features = ['auth_id', 'affiliation', 'fore_name', 'last_name']
X = merged_data[features]
y = merged_data['short_unique_id']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train the Random Forest model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")

merged_data['predicted_short_unique_id'] = model.predict(X)

merged_data
# Out:
#        pmid       auth_id              name_x author_type initials  fore_name  \
# 0  20199141  (20199141,1)        masaki kasai      Person        M     Masaki
# 2  20199141  (20199141,2)      takahiro jikoh      Person        T   Takahiro
# 3  20199141  (20199141,3)  hidefumi fukumitsu      Person        H   Hidefumi
# 4  20199141  (20199141,4)      shoei furukawa      Person        S      Shoei
# 5  22734847  (22734847,1)   matthew f wszolek      Person       MF  Matthew F
#
#    last_name   suffix  orcid_x   name_y  orcid_y  \
# 0      Kasai  unknown  unknown  unknown  unknown
# 2      Jikoh  unknown  unknown  unknown  unknown
# 3  Fukumitsu  unknown  unknown  unknown  unknown
# 4   Furukawa  unknown  unknown  unknown  unknown
# 5    Wszolek  unknown  unknown  unknown  unknown
#
#                                          affiliation              unique_id  \
# 0  Laboratory of Molecular Biology, Gifu Pharmace...  20199141_(20199141,1)
# 2                                            unknown  20199141_(20199141,2)
# 3                                            unknown  20199141_(20199141,3)
# 4                                            unknown  20199141_(20199141,4)
# 5  Institute of Urology, Lahey Clinic Medical Cen...  22734847_(22734847,1)
#
#   short_unique_id
# 0      1c14b34b83
# 2      980f9ac5f8
# 3      48e789ee9b
# 4      56c6682735
# 5      95b24cd9fa
# Accuracy: 0.0
# Classification Report:
#               precision    recall  f1-score   support
#
#   06b3526389       0.00      0.00      0.00       0.0
#   0be99847cd       0.00      0.00      0.00       1.0
#   0c9b66fed6       0.00      0.00      0.00       0.0
#   0ce7d5c45f       0.00      0.00      0.00       1.0
#   133a34619e       0.00      0.00      0.00       0.0
#   14e8683d1a       0.00      0.00      0.00       1.0
#   1c14b34b83       0.00      0.00      0.00       1.0
#   1f3d626767       0.00      0.00      0.00       0.0
#   2077a4fc92       0.00      0.00      0.00       0.0
#   28ba2f3f15       0.00      0.00      0.00       0.0
#   29951eb0b2       0.00      0.00      0.00       1.0
#   2f1c4d9d9a       0.00      0.00      0.00       0.0
#   30bb0c5175       0.00      0.00      0.00       0.0
#   3a7cf60eba       0.00      0.00      0.00       1.0
#   3cdbb6ba36       0.00      0.00      0.00       0.0
#   44026e2e56       0.00      0.00      0.00       0.0
#   45c46819c1       0.00      0.00      0.00       1.0
#   538e905c79       0.00      0.00      0.00       1.0
#   56c6682735       0.00      0.00      0.00       0.0
#   5cb5f3a080       0.00      0.00      0.00       1.0
#   5cee401b09       0.00      0.00      0.00       1.0
#   5f95fe26f7       0.00      0.00      0.00       1.0
#   6254313b62       0.00      0.00      0.00       0.0
#   6688d0c829       0.00      0.00      0.00       1.0
#   6e7894c1ce       0.00      0.00      0.00       1.0
#   71e4d5e362       0.00      0.00      0.00       1.0
#   74d37dffc9       0.00      0.00      0.00       1.0
#   7a54b9458a       0.00      0.00      0.00       0.0
#   7b137c0661       0.00      0.00      0.00       1.0
#   7f30f597d4       0.00      0.00      0.00       0.0
#   8132904937       0.00      0.00      0.00       0.0
#   8140b1f89b       0.00      0.00      0.00       1.0
#   83b74b5390       0.00      0.00      0.00       0.0
#   852fba3e7c       0.00      0.00      0.00       0.0
#   85f885c493       0.00      0.00      0.00       1.0
#   8a24ea065d       0.00      0.00      0.00       0.0
#   8c8095a6d1       0.00      0.00      0.00       1.0
#   9143ebc38a       0.00      0.00      0.00       1.0
#   95117389f2       0.00      0.00      0.00       0.0
#   95b24cd9fa       0.00      0.00      0.00       1.0
#   980f9ac5f8       0.00      0.00      0.00       0.0
#   982f0111f4       0.00      0.00      0.00       0.0
#   9a876e55de       0.00      0.00      0.00       1.0
#   9c7194acd0       0.00      0.00      0.00       1.0
#   b9a593d140       0.00      0.00      0.00       1.0
#   bb08b837f2       0.00      0.00      0.00       0.0
#   c5a387e532       0.00      0.00      0.00       1.0
#   d883f77280       0.00      0.00      0.00       1.0
#   d9fe364f3e       0.00      0.00      0.00       0.0
#   da1ae208e0       0.00      0.00      0.00       0.0
#   e029c6bb21       0.00      0.00      0.00       1.0
#   e1774b443f       0.00      0.00      0.00       1.0
#   e18d2cbd22       0.00      0.00      0.00       0.0
#   e7108e57d0       0.00      0.00      0.00       0.0
#   e77d6cb836       0.00      0.00      0.00       0.0
#   e8ebd4a8b0       0.00      0.00      0.00       1.0
#   e9d3fe6f1f       0.00      0.00      0.00       1.0
#   f9d2d94eb2       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00      31.0
#    macro avg       0.00      0.00      0.00      31.0
# weighted avg       0.00      0.00      0.00      31.0
# C:\Users\Aishwarya Mocherla\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Aishwarya Mocherla\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Aishwarya Mocherla\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Aishwarya Mocherla\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Aishwarya Mocherla\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Aishwarya Mocherla\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#          pmid  auth_id              name_x  author_type  initials  fore_name  \
# 0    20199141        0        masaki kasai       Person         M         57
# 2    20199141        1      takahiro jikoh       Person         T         77
# 3    20199141        2  hidefumi fukumitsu       Person         H         31
# 4    20199141        3      shoei furukawa       Person         S         72
# 5    22734847        4   matthew f wszolek       Person        MF         58
# ..        ...      ...                 ...          ...       ...        ...
# 129  23733708       96      sung-chan shin       Person        SC         75
# 130  23733708       97        yun-sung lim       Person        YS         90
# 131  23733708       98       jin-choon lee       Person        JC         39
# 132  23733708       99       soo-geun wang       Person        SG         74
# 133      pmid      100                name  author_type  initials         94
#
#      last_name   suffix  orcid_x   name_y  orcid_y  affiliation  \
# 0           49  unknown  unknown  unknown  unknown           22
# 2           47  unknown  unknown  unknown  unknown           25
# 3           25  unknown  unknown  unknown  unknown           25
# 4           26  unknown  unknown  unknown  unknown           25
# 5           90  unknown  unknown  unknown  unknown           17
# ..         ...      ...      ...      ...      ...          ...
# 129         75  unknown  unknown  unknown  unknown           25
# 130         53  unknown  unknown  unknown  unknown           25
# 131         50  unknown  unknown  unknown  unknown           25
# 132         86  unknown  unknown  unknown  unknown           25
# 133         94   suffix    orcid  unknown  unknown           25
#
#                  unique_id short_unique_id predicted_short_unique_id
# 0    20199141_(20199141,1)      1c14b34b83                980f9ac5f8
# 2    20199141_(20199141,2)      980f9ac5f8                980f9ac5f8
# 3    20199141_(20199141,3)      48e789ee9b                48e789ee9b
# 4    20199141_(20199141,4)      56c6682735                56c6682735
# 5    22734847_(22734847,1)      95b24cd9fa                56c6682735
# ..                     ...             ...                       ...
# 129  23733708_(23733708,2)      e8ebd4a8b0                30bb0c5175
# 130  23733708_(23733708,3)      c5a387e532                133a34619e
# 131  23733708_(23733708,4)      133a34619e                133a34619e
# 132  23733708_(23733708,5)      84dd131abc                84dd131abc
# 133           pmid_auth_id      660a0d9433                660a0d9433
#
# [101 rows x 15 columns]

# %%
selected_columns_merged_data = merged_data[['pmid', 'initials', 'short_unique_id']]
selected_columns_id = author_id[['ident', 'name','orcid']]
selected_columns_name = author_name[['auth_id','author_type','initials','fore_name','last_name']]
selected_columns_affiliatiom = author_affiliation[['affiliation']]
selected_columns_merged_data2 = merged_data[['short_unique_id']]

n_merged_data = pd.concat([selected_columns_merged_data, selected_columns_id, selected_columns_name, selected_columns_affiliatiom, selected_columns_merged_data2], axis=1)
n_merged_data
# Out:
#          pmid initials short_unique_id  \
# 0    20199141        M      1c14b34b83
# 2    20199141        T      980f9ac5f8
# 3    20199141        H      48e789ee9b
# 4    20199141        S      56c6682735
# 5    22734847       MF      95b24cd9fa
# ..        ...      ...             ...
# 196       NaN      NaN             NaN
# 197       NaN      NaN             NaN
# 198       NaN      NaN             NaN
# 199       NaN      NaN             NaN
# 200       NaN      NaN             NaN
#
#                                                  ident                  name  \
# 0    https://purl.humanatlas.io/graph/hra-lit/v0.6#...             Weijie Du
# 2    https://purl.humanatlas.io/graph/hra-lit/v0.6#...      Aashay Kekatpure
# 3    https://purl.humanatlas.io/graph/hra-lit/v0.6#...               V Rigau
# 4    https://purl.humanatlas.io/graph/hra-lit/v0.6#...           Wen-Shi Wei
# 5    https://purl.humanatlas.io/graph/hra-lit/v0.6#...   Theodore H Schwartz
# ..                                                 ...                   ...
# 196  https://purl.humanatlas.io/graph/hra-lit/v0.6#...            Haiyue Dai
# 197  https://purl.humanatlas.io/graph/hra-lit/v0.6#...  Natalia Lopez-Andres
# 198  https://purl.humanatlas.io/graph/hra-lit/v0.6#...            L van Rijn
# 199  https://purl.humanatlas.io/graph/hra-lit/v0.6#...          Vijay Gadgil
# 200                                                NaN                   NaN
#
#        orcid       auth_id author_type initials  fore_name  last_name  \
# 0    unknown  (20199141,1)      Person        M     Masaki      Kasai
# 2    unknown  (20199141,3)      Person        H   Hidefumi  Fukumitsu
# 3    unknown  (20199141,4)      Person        S      Shoei   Furukawa
# 4    unknown  (22734847,1)      Person       MF  Matthew F    Wszolek
# 5    unknown  (22734847,2)      Person        D      David      Canes
# ..       ...           ...         ...      ...        ...        ...
# 196  unknown  (23733708,1)      Person       YS    Yoon Se        Lee
# 197  unknown  (23733708,2)      Person       SC  Sung-Chan       Shin
# 198  unknown  (23733708,3)      Person       YS   Yun-Sung        Lim
# 199  unknown  (23733708,4)      Person       JC  Jin-Choon        Lee
# 200      NaN  (23733708,5)      Person       SG   Soo-Geun       Wang
#
#                                            affiliation short_unique_id
# 0    Laboratory of Molecular Biology, Gifu Pharmace...      1c14b34b83
# 2    Bioengineering Department, Politecnico di Mila...      980f9ac5f8
# 3    Mechanics of Materials and Constructions (MeMC...      48e789ee9b
# 4    1 Department of Child and Adolescent Psychiatr...      56c6682735
# 5    2 Department of Child Psychiatry and Sleep cen...      95b24cd9fa
# ..                                                 ...             ...
# 196  Hans Popper Laboratory of Molecular Hepatology...             NaN
# 197  State Key Laboratory of Cancer Biology and Xij...             NaN
# 198  Biostatistics Unit, Department of Health Scien...             NaN
# 199  Department of Obstetrics and Gynecology, Sant&...             NaN
# 200                                                NaN             NaN
#
# [201 rows x 13 columns]

# %%
final_merged_data = n_merged_data.dropna(subset=['short_unique_id'])

# %%
author_names_and_uid = final_merged_data.rename(columns={'short_unique_id': 'UId'})
author_names_and_uid
# Out:
#          pmid  initials         UId  \
# 0    20199141         M  1c14b34b83
# 2    20199141         T  980f9ac5f8
# 3    20199141         H  48e789ee9b
# 4    20199141         S  56c6682735
# 5    22734847        MF  95b24cd9fa
# ..        ...       ...         ...
# 129  23733708        SC  e8ebd4a8b0
# 130  23733708        YS  c5a387e532
# 131  23733708        JC  133a34619e
# 132  23733708        SG  84dd131abc
# 133      pmid  initials  660a0d9433
#
#                                                  ident  \
# 0    https://purl.humanatlas.io/graph/hra-lit/v0.6#...
# 2    https://purl.humanatlas.io/graph/hra-lit/v0.6#...
# 3    https://purl.humanatlas.io/graph/hra-lit/v0.6#...
# 4    https://purl.humanatlas.io/graph/hra-lit/v0.6#...
# 5    https://purl.humanatlas.io/graph/hra-lit/v0.6#...
# ..                                                 ...
# 129  https://purl.humanatlas.io/graph/hra-lit/v0.6#...
# 130  https://purl.humanatlas.io/graph/hra-lit/v0.6#...
# 131  https://purl.humanatlas.io/graph/hra-lit/v0.6#...
# 132  https://purl.humanatlas.io/graph/hra-lit/v0.6#...
# 133  https://purl.humanatlas.io/graph/hra-lit/v0.6#...
#
#                                name                                  orcid  \
# 0                         Weijie Du                                unknown
# 2                  Aashay Kekatpure                                unknown
# 3                           V Rigau                                unknown
# 4                       Wen-Shi Wei                                unknown
# 5               Theodore H Schwartz                                unknown
# ..                              ...                                    ...
# 129                 John M Costello  https://orcid.org/0000-0001-7713-0258
# 130                   Hassan Sajjad                                unknown
# 131  Daniele Cristine Krebs Ribeiro                                unknown
# 132                     Yiding Wang                                unknown
# 133               Maximilian L Buja                                unknown
#
#           auth_id author_type initials                 fore_name  last_name  \
# 0    (20199141,1)      Person        M                    Masaki      Kasai
# 2    (20199141,3)      Person        H                  Hidefumi  Fukumitsu
# 3    (20199141,4)      Person        S                     Shoei   Furukawa
# 4    (22734847,1)      Person       MF                 Matthew F    Wszolek
# 5    (22734847,2)      Person        D                     David      Canes
# ..            ...         ...      ...                       ...        ...
# 129  (23592528,3)      Person       CM      C&Atilde;&copy;lia M     Strunz
# 130  (23592528,4)      Person        A                 Alexandre     Soeiro
# 131  (23592528,5)      Person        M      M&Atilde;&iexcl;rcio     Santos
# 132  (23592528,6)      Person        F      Fl&Atilde;&iexcl;vio   Pivateli
# 133  (23592528,7)      Person       JL  Jos&Atilde;&copy; Luis B      Jacob
#
#                                            affiliation         UId
# 0    Laboratory of Molecular Biology, Gifu Pharmace...  1c14b34b83
# 2    Bioengineering Department, Politecnico di Mila...  980f9ac5f8
# 3    Mechanics of Materials and Constructions (MeMC...  48e789ee9b
# 4    1 Department of Child and Adolescent Psychiatr...  56c6682735
# 5    2 Department of Child Psychiatry and Sleep cen...  95b24cd9fa
# ..                                                 ...         ...
# 129  Delta-Ultrasound Diagnostic Center in Obstetri...  e8ebd4a8b0
# 130  Department of Otorhinolaryngology - Head and N...  c5a387e532
# 131  Department of Otolaryngology, Singapore Genera...  133a34619e
# 132  Division of Cardiology and Cardiovascular Surg...  84dd131abc
# 133  Cavanagh Heart Center at Banner Good Samaritan...  660a0d9433
#
# [101 rows x 13 columns]

# %%
author_names_and_uid.to_csv('author_details_and_uid.csv', index=False)
